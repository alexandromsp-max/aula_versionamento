# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandromsp-max/aula_versionamento/blob/main/validacao_nota.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
5### validação  da nota Bimestral    7.0 , 75
### 7..0  >> Aprovado
### 6..9  >> Recuperação alteração

nota = float(input("ïnforma sua bimestral:  "))

if nota >=7.0:
  print('Aprovado')
  print("Parabéns")
else:
  print("Recuperação")
  print('tentar novamente')
# Out:
# ïnforma sua bimestral:  7
# Aprovado
# Parabéns
